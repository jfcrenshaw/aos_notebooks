# %%
import numpy as np
import matplotlib.pyplot as plt
from ml_aos.dataloader import Donuts

# %%
donuts = Donuts()

# %%
# uncomment this block to plot lots of donuts
# this is useful for determining which donuts to plot below
"""
fig, axes = plt.subplots(20, 10, figsize=(12, 24), constrained_layout=True)

for i, ax in enumerate(axes.flatten()):
    ax.imshow(np.array(donuts[i]["image"]), origin="lower")
    ax.set(title=i, xticks=[], yticks=[])
""";

# %%
indices = [
    31, 51, 49, 26, 
    174, 189, 161, 131,
]

fig, axes = plt.subplots(2, 4, figsize=(6, 3), constrained_layout=True, dpi=120)

for idx, ax in zip(indices, axes.flatten()):
    ax.imshow(np.array(donuts[idx]["image"]), origin="lower")
    ax.set(xticks=[], yticks=[])

fig.savefig("figures/donuts.png", dpi=600)
